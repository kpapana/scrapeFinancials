# %%
import yfinance as yf   
from datetime import datetime
import lxml
from lxml import html
import requests
import numpy as np
import pandas as pd
import time
import random

# %%
def get_page(url):
    # Set up the request headers that we're going to use, to simulate
    # a request by the Chrome browser. Simulating a request from a browser
    # is generally good practice when building a scraper
    headers = {
        'scheme': 'https',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
        'accept-encoding': 'gzip, deflate, br',
        'accept-language': 'en-US,en;q=0.9,te;q=0.8',
        'cache-control': 'max-age=0',
        'pragma': 'no-cache',
        'referer': 'https://s.yimg.com/rq/darla/4-7-1/html/r-sf.html',
        'sec-fetch-dest': 'image',
        'sec-fetch-mode': 'no-cors',
        'sec-fetch-site': 'cross-site',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Safari/537.36'
    }

    return requests.get(url, headers=headers)

# %%
symbols = ['3MINDIA']
for symbol in symbols:
    page = get_page("https://www.screener.in/company/"+symbol+"/")
    print(type(page.content))
    tree = page.content.decode("utf-8").replace("\\n","\n")
    path = r"C:\Users\karth\OneDrive\shared\Scrapped_data\scrapped\\"+symbol+'.html'
    print(path)
    f = open(path, 'w',encoding='utf-8')
    f.write(tree)
    f.close()
    print("got ",symbol)
# Out:
# <class 'bytes'>
# C:\Users\karth\OneDrive\shared\Scrapped_data\scrapped\\3MINDIA.html
# got  3MINDIA

# %%
tableData = pd.read_html(r'C:\Users\karth\OneDrive\shared\Scrapped_data\scrapped\3MINDIA.html')
print(f'Total tables: {len(tableData)}')

tableData
# Out:
# Total tables: 10
# [           Unnamed: 0 Dec 2017 Mar 2018 Jun 2018 Sep 2018 Dec 2018 Mar 2019  \
#  0             Sales +      646      679      701      683      736      689
#  1          Expenses +      519      529      546      588      579      591
#  2    Operating Profit      127      150      154       95      157       98
#  3               OPM %      20%      22%      22%      14%      21%      14%
#  4        Other Income       25        8        9       15       10        2
#  5            Interest        0        1        0        0        0        1
#  6        Depreciation       10       10       10       11       10       10
#  7   Profit before tax      141      146      153       99      156       89
#  8               Tax %      35%      36%      35%      35%      35%      35%
#  9          Net Profit       92       93      100       64      101       58
#  10          EPS in Rs    81.40    82.60    88.42    56.67    90.00    51.62
#  11                NaN    Notes    Notes    Notes    Notes    Notes    Notes
#
#     Jun 2019 Sep 2019 Dec 2019 Mar 2020 Jun 2020 Sep 2020
#  0       742      702      694      627      320      648
#  1       601      583      601      639      365      541
#  2       141      119       93      -11      -46      107
#  3       19%      17%      13%      -2%     -14%      16%
#  4         6       10       13       11        7        6
#  5         1        1        1        1        1        0
#  6        14       13       14       15       14       16
#  7       131      115       91      -16      -54       96
#  8       35%      20%      25%     -60%      26%      26%
#  9        85       92       68      -26      -40       71
#  10    75.37    81.80    60.14   -22.93   -35.43    62.89
#  11    Notes    Notes    Notes    Notes    Notes    Notes  ,
#             Unnamed: 0 Dec 2008 Mar 2010 Mar 2011 Mar 2012 Mar 2013 Mar 2014  \
#  0             Sales +      742     1087     1191     1405     1574     1742
#  1          Expenses +      654      948     1035     1283     1463     1630
#  2    Operating Profit       88      138      156      122      112      112
#  3               OPM %      12%      13%      13%       9%       7%       6%
#  4        Other Income       11       20       11        5       10       19
#  5            Interest        0        1        2        4       10       15
#  6        Depreciation        7       17       17       27       36       48
#  7   Profit before tax       91      141      148       96       75       69
#  8               Tax %      37%      34%      33%      33%      30%      38%
#  9          Net Profit       57       93       99       65       52       43
#  10          EPS in Rs    51.01    82.41    87.70    57.50    46.40    38.16
#  11  Dividend Payout %       0%       0%       0%       0%       0%       0%
#
#     Mar 2015 Mar 2016 Mar 2017 Mar 2018 Mar 2019 Mar 2020    TTM
#  0      1840     2140     2363     2556     2809     2765   2289
#  1      1636     1803     1994     2076     2301     2425   2146
#  2       204      337      369      480      508      340    142
#  3       11%      16%      16%      19%      18%      12%     6%
#  4        14       18       49       44       33       42     38
#  5         4        2        2        2        1        4      3
#  6        50       49       47       42       42       57     60
#  7       165      303      369      480      497      320    117
#  8       34%      36%      35%      35%      35%      32%    NaN
#  9       108      195      241      311      323      219     73
#  10    96.17   172.89   213.72   275.67   286.72   194.38  64.67
#  11       0%       0%       0%       0%       0%       0%    NaN  ,
#    Compounded Sales Growth Compounded Sales Growth.1
#  0               10 Years:                       10%
#  1                5 Years:                        8%
#  2                3 Years:                        5%
#  3                    TTM:                      -20%,
#    Compounded Profit Growth Compounded Profit Growth.1
#  0                10 Years:                         9%
#  1                 5 Years:                        15%
#  2                 3 Years:                        -3%
#  3                     TTM:                       -78%,
#    Stock Price CAGR Stock Price CAGR.1
#  0        10 Years:                19%
#  1         5 Years:                16%
#  2         3 Years:                 3%
#  3          1 Year:                -8%,
#    Return on Equity Return on Equity.1
#  0        10 Years:                16%
#  1         5 Years:                18%
#  2         3 Years:                17%
#  3       Last Year:                11%,
#              Unnamed: 0  Dec 2008  Mar 2010  Mar 2011  Mar 2012  Mar 2013  \
#  0      Share Capital +        11        11        11        11        11
#  1             Reserves       336       429       528       593       645
#  2           Borrowings         0         0        12        76       174
#  3  Other Liabilities +       129       169       200       241       233
#  4    Total Liabilities       477       610       751       921      1063
#  5       Fixed Assets +       116       141       165       290       300
#  6                 CWIP        27        40        94        21       121
#  7          Investments         0         0         0         0         0
#  8       Other Assets +       334       429       492       611       642
#  9         Total Assets       477       610       751       921      1063
#
#     Mar 2014  Mar 2015  Mar 2016  Mar 2017  Mar 2018  Mar 2019  Mar 2020  \
#  0        11        11        11        11        11        11        11
#  1       688       796       977      1215      1525      1848      2064
#  2       121        14        11        10         9        14        42
#  3       267       306       430       695       589       621       537
#  4      1088      1128      1429      1932      2135      2494      2653
#  5       418       388       349       315       285       269       287
#  6         7         1         1         2         6        10         7
#  7         0         0         0         0         0       585       505
#  8       662       739      1078      1614      1844      1629      1855
#  9      1088      1128      1429      1932      2135      2494      2653
#
#     Sep 2020
#  0        11
#  1      2093
#  2        31
#  3       484
#  4      2619
#  5       265
#  6         5
#  7       505
#  8      1844
#  9      2619  ,
#                         Unnamed: 0  Dec 2008  Mar 2010  Mar 2011  Mar 2012  \
#  0  Cash from Operating Activity +         1       106        53        21
#  1  Cash from Investing Activity +       -44       -52      -119       -71
#  2  Cash from Financing Activity +         0         0        12        53
#  3                   Net Cash Flow       -44        53       -55         3
#
#     Mar 2013  Mar 2014  Mar 2015  Mar 2016  Mar 2017  Mar 2018  Mar 2019  \
#  0        64       120       177       261       365        29       267
#  1      -141       -47        -4         1        12        18      -590
#  2        83       -73      -119        -5        -4        -2         4
#  3         6         0        54       257       373        45      -319
#
#     Mar 2020
#  0       218
#  1         1
#  2       -24
#  3       195  ,
#             Unnamed: 0 Dec 2008 Mar 2010 Mar 2011 Mar 2012 Mar 2013 Mar 2014  \
#  0              ROCE %      28%      36%      30%      16%      11%      10%
#  1         Debtor Days       53       49       60       61       62       56
#  2  Inventory Turnover     4.82     5.38     4.70     4.43     4.37     4.45
#
#    Mar 2015 Mar 2016 Mar 2017 Mar 2018 Mar 2019 Mar 2020
#  0      21%      34%      33%      35%      29%      16%
#  1       49       54       63       76       71       67
#  2     3.90     4.13     4.26     3.97     4.14     4.12  ,
#      Unnamed: 0  Mar 2018  Jun 2018  Sep 2018  Dec 2018  Mar 2019  Jun 2019  \
#  0  Promoters +     75.00      75.0     75.00     75.00     75.00     75.00
#  1       FIIs +      9.17       9.0      8.62      8.32      8.29      8.26
#  2       DIIs +      2.05       2.0      1.93      2.23      2.22      2.15
#  3     Public +     13.78      14.0     14.45     14.45     14.49     14.59
#
#     Sep 2019  Dec 2019  Mar 2020  Jun 2020  Sep 2020  Dec 2020
#  0     75.00     75.00     75.00     75.00     75.00     75.00
#  1      6.79      5.19      4.85      3.32      3.59      4.28
#  2      3.17      4.11      4.42      6.97      7.08      6.78
#  3     15.04     15.70     15.73     14.71     14.33     13.94  ]

# %%
import lxml.html as LH
import requests
import pandas as pd
def text(elt):
    return elt.text_content().replace(u'\xa0', u' ')

url = r'https://www.screener.in/company/3MINDIA/consolidated/'
r = requests.get(url)
root = LH.fromstring(r.content)

for table in root.xpath('//*[@id="peers"]'):
    print("in for")
    #header = [text(th) for th in table.xpath('//th')]        # 1
    data = [[text(td) for td in tr.xpath('td')]  
            for tr in table.xpath('//tr')]                   # 2
    data = [row for row in data if True]    # 3 
    data = pd.DataFrame(data)                # 4
    data
data
